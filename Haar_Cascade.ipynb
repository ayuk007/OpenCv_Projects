# %%
# !wget https://i.ytimg.com/vi/bAHbqTlxhhA/maxresdefault.jpg
# Out:
# --2023-01-30 18:29:01--  https://i.ytimg.com/vi/bAHbqTlxhhA/maxresdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 142.251.111.119, 142.251.16.119, 142.251.163.119, ...
# Connecting to i.ytimg.com (i.ytimg.com)|142.251.111.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157352 (154K) [image/jpeg]
# Saving to: ‘maxresdefault.jpg’
#
# maxresdefault.jpg   100%[===================>] 153.66K  --.-KB/s    in 0.02s
#
# 2023-01-30 18:29:02 (6.91 MB/s) - ‘maxresdefault.jpg’ saved [157352/157352]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('/content/maxresdefault.jpg')
img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (20, 20))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.show()
plt.figure(figsize = (20, 20))
plt.subplot(1, 2, 2)
plt.imshow(img_RGB)
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (15, 15))
plt.imshow(img_gray)

# %%
haar_cascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
faces_rect = haar_cascade.detectMultiScale(img_gray, 1.1, 9)

# %%
for (x, y, w, h) in faces_rect:
  cv2.rectangle(img_RGB, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.figure(figsize = (15, 15))
plt.imshow(img_RGB)
